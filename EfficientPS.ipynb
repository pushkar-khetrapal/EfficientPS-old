# %% [markdown]
# <a href="https://colab.research.google.com/github/pushkar-khetrapal/EfficientPS/blob/master/EfficientPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install efficientnet_pytorch
# !pip install git+https://github.com/mapillary/inplace_abn
# Out:
# Collecting efficientnet_pytorch
#   Downloading https://files.pythonhosted.org/packages/b8/cb/0309a6e3d404862ae4bc017f89645cf150ac94c14c88ef81d215c8e52925/efficientnet_pytorch-0.6.3.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from efficientnet_pytorch) (1.5.1+cu101)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->efficientnet_pytorch) (1.18.5)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-cp36-none-any.whl size=12422 sha256=477c5e925ab560851accd402e3eba79756803522582b98977be4cf8178181907
#   Stored in directory: /root/.cache/pip/wheels/42/1e/a9/2a578ba9ad04e776e80bf0f70d8a7f4c29ec0718b92d8f6ccd
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.6.3
# Collecting git+https://github.com/mapillary/inplace_abn
#   Cloning https://github.com/mapillary/inplace_abn to /tmp/pip-req-build-adf51yab
#   Running command git clone -q https://github.com/mapillary/inplace_abn /tmp/pip-req-build-adf51yab
# Building wheels for collected packages: inplace-abn
#   Building wheel for inplace-abn (setup.py) ... done
#   Created wheel for inplace-abn: filename=inplace_abn-1.0.12-cp36-cp36m-linux_x86_64.whl size=3264503 sha256=d032e4035ca4cff8b5bf97f5835a154072dffc8f96561bb921a983f42f446164
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1lwjc2mn/wheels/fe/0b/49/1303ca37166cc1be8784e2367a172133634dcd864a9df0ab56
# Successfully built inplace-abn
# Installing collected packages: inplace-abn
# Successfully installed inplace-abn-1.0.12

# %%
from efficientnet_pytorch import utils

# %%
import collections
import re
# Parameters for the entire model (stem, all blocks, and head)
GlobalParams = collections.namedtuple('GlobalParams', [
    'width_coefficient', 'depth_coefficient', 'image_size', 'dropout_rate',
    'num_classes', 'batch_norm_momentum', 'batch_norm_epsilon',
    'drop_connect_rate', 'depth_divisor', 'min_depth'])

# Parameters for an individual model block
BlockArgs = collections.namedtuple('BlockArgs', [
    'num_repeat', 'kernel_size', 'stride', 'expand_ratio',
    'input_filters', 'output_filters', 'se_ratio', 'id_skip'])

# %%
def efficientnet_params(model_name):
    """ Map EfficientNet model name to parameter coefficients. """
    params_dict = {
        # Coefficients:   width,depth,res,dropout
        'efficientnet-b0': (1.0, 1.0, 224, 0.2),
        'efficientnet-b1': (1.0, 1.1, 240, 0.2),
        'efficientnet-b2': (1.1, 1.2, 260, 0.3),
        'efficientnet-b3': (1.2, 1.4, 300, 0.3),
        'efficientnet-b4': (1.4, 1.8, 380, 0.4),
        'efficientnet-b5': (1.6, 2.2, 456, 0.4),
        'efficientnet-b6': (1.8, 2.6, 528, 0.5),
        'efficientnet-b7': (2.0, 3.1, 600, 0.5),
        'efficientnet-b8': (2.2, 3.6, 672, 0.5),
        'efficientnet-l2': (4.3, 5.3, 800, 0.5),
    }
    return params_dict[model_name]

class BlockDecoder(object):
    """ Block Decoder for readability, straight from the official TensorFlow repository """

    @staticmethod
    def _decode_block_string(block_string):
        """ Gets a block through a string notation of arguments. """
        assert isinstance(block_string, str)

        ops = block_string.split('_')
        options = {}
        for op in ops:
            splits = re.split(r'(\d.*)', op)
            if len(splits) >= 2:
                key, value = splits[:2]
                options[key] = value

        # Check stride
        assert (('s' in options and len(options['s']) == 1) or
                (len(options['s']) == 2 and options['s'][0] == options['s'][1]))

        return BlockArgs(
            kernel_size=int(options['k']),
            num_repeat=int(options['r']),
            input_filters=int(options['i']),
            output_filters=int(options['o']),
            expand_ratio=int(options['e']),
            id_skip=('noskip' not in block_string),
            se_ratio=float(options['se']) if 'se' in options else None,
            stride=[int(options['s'][0])])

    @staticmethod
    def _encode_block_string(block):
        """Encodes a block to a string."""
        args = [
            'r%d' % block.num_repeat,
            'k%d' % block.kernel_size,
            's%d%d' % (block.strides[0], block.strides[1]),
            'e%s' % block.expand_ratio,
            'i%d' % block.input_filters,
            'o%d' % block.output_filters
        ]
        if 0 < block.se_ratio <= 1:
            args.append('se%s' % block.se_ratio)
        if block.id_skip is False:
            args.append('noskip')
        return '_'.join(args)

    @staticmethod
    def decode(string_list):
        """
        Decodes a list of string notations to specify blocks inside the network.

        :param string_list: a list of strings, each string is a notation of block
        :return: a list of BlockArgs namedtuples of block args
        """
        assert isinstance(string_list, list)
        blocks_args = []
        for block_string in string_list:
            blocks_args.append(BlockDecoder._decode_block_string(block_string))
        return blocks_args

    @staticmethod
    def encode(blocks_args):
        """
        Encodes a list of BlockArgs to a list of strings.

        :param blocks_args: a list of BlockArgs namedtuples of block args
        :return: a list of strings, each string is a notation of block
        """
        block_strings = []
        for block in blocks_args:
            block_strings.append(BlockDecoder._encode_block_string(block))
        return block_strings


def efficientnet(width_coefficient=None, depth_coefficient=None, dropout_rate=0.2,
                 drop_connect_rate=0.2, image_size=None, num_classes=1000):
    """ Creates a efficientnet model. """

    blocks_args = [
        'r1_k3_s11_e1_i32_o16_se0.25', 'r2_k3_s22_e6_i16_o24_se0.25',
        'r2_k5_s22_e6_i24_o40_se0.25', 'r3_k3_s22_e6_i40_o80_se0.25',
        'r3_k5_s11_e6_i80_o112_se0.25', 'r4_k5_s22_e6_i112_o192_se0.25',
        'r1_k3_s11_e6_i192_o320_se0.25',
    ]
    blocks_args = BlockDecoder.decode(blocks_args)

    global_params = GlobalParams(
        batch_norm_momentum=0.99,
        batch_norm_epsilon=1e-3,
        dropout_rate=dropout_rate,
        drop_connect_rate=drop_connect_rate,
        # data_format='channels_last',  # removed, this is always true in PyTorch
        num_classes=num_classes,
        width_coefficient=width_coefficient,
        depth_coefficient=depth_coefficient,
        depth_divisor=8,
        min_depth=None,
        image_size=image_size,
    )

    return blocks_args, global_params


def get_model_params(model_name, override_params):
    """ Get the block args and global params for a given model """
    if model_name.startswith('efficientnet'):
        w, d, s, p = efficientnet_params(model_name)
        # note: all models have drop connect rate = 0.2
        blocks_args, global_params = efficientnet(
            width_coefficient=w, depth_coefficient=d, dropout_rate=p, image_size=s)
    else:
        raise NotImplementedError('model name is not pre-defined: %s' % model_name)
    if override_params:
        # ValueError will be raised here if override_params has fields not included in global_params.
        global_params = global_params._replace(**override_params)
    return blocks_args, global_params

# %%
override_params={'num_classes': 1000}
x = get_model_params( 'efficientnet-b5', override_params )

# %%
x[0]
# Out:
# [BlockArgs(num_repeat=1, kernel_size=3, stride=[1], expand_ratio=1, input_filters=32, output_filters=16, se_ratio=0.25, id_skip=True),
#  BlockArgs(num_repeat=2, kernel_size=3, stride=[2], expand_ratio=6, input_filters=16, output_filters=24, se_ratio=0.25, id_skip=True),
#  BlockArgs(num_repeat=2, kernel_size=5, stride=[2], expand_ratio=6, input_filters=24, output_filters=40, se_ratio=0.25, id_skip=True),
#  BlockArgs(num_repeat=3, kernel_size=3, stride=[2], expand_ratio=6, input_filters=40, output_filters=80, se_ratio=0.25, id_skip=True),
#  BlockArgs(num_repeat=3, kernel_size=5, stride=[1], expand_ratio=6, input_filters=80, output_filters=112, se_ratio=0.25, id_skip=True),
#  BlockArgs(num_repeat=4, kernel_size=5, stride=[2], expand_ratio=6, input_filters=112, output_filters=192, se_ratio=0.25, id_skip=True),
#  BlockArgs(num_repeat=1, kernel_size=3, stride=[1], expand_ratio=6, input_filters=192, output_filters=320, se_ratio=0.25, id_skip=True)]

# %%
from efficientnet_pytorch import EfficientNet
model = EfficientNet(x[0],x[1] )

# %%
import torch

# %%
# !pip install torch-summary
# Out:
# Collecting torch-summary
#   Downloading https://files.pythonhosted.org/packages/34/c9/8b07f274404f08361710d971fde3164577c5f0ef984ecb1dd6e9e0541f99/torch_summary-1.3.3-py3-none-any.whl
# Installing collected packages: torch-summary
# Successfully installed torch-summary-1.3.3

# %%
import torch
from torchsummary import summary

summary(model, torch.zeros((1, 3, 1024, 2048)))
#print(summary(model, torch.zeros((1, 3, 1024, 2048)), show_input=True, show_hierarchical=True))
# Out:
# ----------------------------------------------------------------------------------------------------
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# ├─Conv2dStaticSamePadding: 1-1                     [-1, 48, 512, 1024]       --
# |    └─ZeroPad2d: 2-1                              [-1, 3, 1025, 2049]       --
# ├─BatchNorm2d: 1-2                                 [-1, 48, 512, 1024]       96
# ├─MemoryEfficientSwish: 1-3                        [-1, 48, 512, 1024]       --
# ├─Conv2dStaticSamePadding: 1-4                     [-1, 2048, 32, 64]        --
# |    └─MBConvBlock: 2-2                            [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-1           [-1, 48, 512, 1024]       432
# |    |    └─BatchNorm2d: 3-2                       [-1, 48, 512, 1024]       96
# |    |    └─MemoryEfficientSwish: 3-3              [-1, 48, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-4           [-1, 12, 1, 1]            588
# |    |    └─MemoryEfficientSwish: 3-5              [-1, 12, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-6           [-1, 48, 1, 1]            624
# |    |    └─Conv2dStaticSamePadding: 3-7           [-1, 24, 512, 1024]       1,152
# |    |    └─BatchNorm2d: 3-8                       [-1, 24, 512, 1024]       48
# |    └─MBConvBlock: 2-3                            [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-9           [-1, 24, 512, 1024]       216
# |    |    └─BatchNorm2d: 3-10                      [-1, 24, 512, 1024]       48
# |    |    └─MemoryEfficientSwish: 3-11             [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-12          [-1, 6, 1, 1]             150
# |    |    └─MemoryEfficientSwish: 3-13             [-1, 6, 1, 1]             --
# |    |    └─Conv2dStaticSamePadding: 3-14          [-1, 24, 1, 1]            168
# |    |    └─Conv2dStaticSamePadding: 3-15          [-1, 24, 512, 1024]       576
# |    |    └─BatchNorm2d: 3-16                      [-1, 24, 512, 1024]       48
# |    └─MBConvBlock: 2-4                            [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-17          [-1, 24, 512, 1024]       216
# |    |    └─BatchNorm2d: 3-18                      [-1, 24, 512, 1024]       48
# |    |    └─MemoryEfficientSwish: 3-19             [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-20          [-1, 6, 1, 1]             150
# |    |    └─MemoryEfficientSwish: 3-21             [-1, 6, 1, 1]             --
# |    |    └─Conv2dStaticSamePadding: 3-22          [-1, 24, 1, 1]            168
# |    |    └─Conv2dStaticSamePadding: 3-23          [-1, 24, 512, 1024]       576
# |    |    └─BatchNorm2d: 3-24                      [-1, 24, 512, 1024]       48
# |    └─MBConvBlock: 2-5                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-25          [-1, 144, 512, 1024]      3,456
# |    |    └─BatchNorm2d: 3-26                      [-1, 144, 512, 1024]      288
# |    |    └─MemoryEfficientSwish: 3-27             [-1, 144, 512, 1024]      --
# |    |    └─Conv2dStaticSamePadding: 3-28          [-1, 144, 256, 512]       1,296
# |    |    └─BatchNorm2d: 3-29                      [-1, 144, 256, 512]       288
# |    |    └─MemoryEfficientSwish: 3-30             [-1, 144, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-31          [-1, 6, 1, 1]             870
# |    |    └─MemoryEfficientSwish: 3-32             [-1, 6, 1, 1]             --
# |    |    └─Conv2dStaticSamePadding: 3-33          [-1, 144, 1, 1]           1,008
# |    |    └─Conv2dStaticSamePadding: 3-34          [-1, 40, 256, 512]        5,760
# |    |    └─BatchNorm2d: 3-35                      [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-6                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-36          [-1, 240, 256, 512]       9,600
# |    |    └─BatchNorm2d: 3-37                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-38             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-39          [-1, 240, 256, 512]       2,160
# |    |    └─BatchNorm2d: 3-40                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-41             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-42          [-1, 10, 1, 1]            2,410
# |    |    └─MemoryEfficientSwish: 3-43             [-1, 10, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-44          [-1, 240, 1, 1]           2,640
# |    |    └─Conv2dStaticSamePadding: 3-45          [-1, 40, 256, 512]        9,600
# |    |    └─BatchNorm2d: 3-46                      [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-7                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-47          [-1, 240, 256, 512]       9,600
# |    |    └─BatchNorm2d: 3-48                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-49             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-50          [-1, 240, 256, 512]       2,160
# |    |    └─BatchNorm2d: 3-51                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-52             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-53          [-1, 10, 1, 1]            2,410
# |    |    └─MemoryEfficientSwish: 3-54             [-1, 10, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-55          [-1, 240, 1, 1]           2,640
# |    |    └─Conv2dStaticSamePadding: 3-56          [-1, 40, 256, 512]        9,600
# |    |    └─BatchNorm2d: 3-57                      [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-8                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-58          [-1, 240, 256, 512]       9,600
# |    |    └─BatchNorm2d: 3-59                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-60             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-61          [-1, 240, 256, 512]       2,160
# |    |    └─BatchNorm2d: 3-62                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-63             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-64          [-1, 10, 1, 1]            2,410
# |    |    └─MemoryEfficientSwish: 3-65             [-1, 10, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-66          [-1, 240, 1, 1]           2,640
# |    |    └─Conv2dStaticSamePadding: 3-67          [-1, 40, 256, 512]        9,600
# |    |    └─BatchNorm2d: 3-68                      [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-9                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-69          [-1, 240, 256, 512]       9,600
# |    |    └─BatchNorm2d: 3-70                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-71             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-72          [-1, 240, 256, 512]       2,160
# |    |    └─BatchNorm2d: 3-73                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-74             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-75          [-1, 10, 1, 1]            2,410
# |    |    └─MemoryEfficientSwish: 3-76             [-1, 10, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-77          [-1, 240, 1, 1]           2,640
# |    |    └─Conv2dStaticSamePadding: 3-78          [-1, 40, 256, 512]        9,600
# |    |    └─BatchNorm2d: 3-79                      [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-10                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-80          [-1, 240, 256, 512]       9,600
# |    |    └─BatchNorm2d: 3-81                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-82             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-83          [-1, 240, 128, 256]       6,000
# |    |    └─BatchNorm2d: 3-84                      [-1, 240, 128, 256]       480
# |    |    └─MemoryEfficientSwish: 3-85             [-1, 240, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-86          [-1, 10, 1, 1]            2,410
# |    |    └─MemoryEfficientSwish: 3-87             [-1, 10, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-88          [-1, 240, 1, 1]           2,640
# |    |    └─Conv2dStaticSamePadding: 3-89          [-1, 64, 128, 256]        15,360
# |    |    └─BatchNorm2d: 3-90                      [-1, 64, 128, 256]        128
# |    └─MBConvBlock: 2-11                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-91          [-1, 384, 128, 256]       24,576
# |    |    └─BatchNorm2d: 3-92                      [-1, 384, 128, 256]       768
# |    |    └─MemoryEfficientSwish: 3-93             [-1, 384, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-94          [-1, 384, 128, 256]       9,600
# |    |    └─BatchNorm2d: 3-95                      [-1, 384, 128, 256]       768
# |    |    └─MemoryEfficientSwish: 3-96             [-1, 384, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-97          [-1, 16, 1, 1]            6,160
# |    |    └─MemoryEfficientSwish: 3-98             [-1, 16, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-99          [-1, 384, 1, 1]           6,528
# |    |    └─Conv2dStaticSamePadding: 3-100         [-1, 64, 128, 256]        24,576
# |    |    └─BatchNorm2d: 3-101                     [-1, 64, 128, 256]        128
# |    └─MBConvBlock: 2-12                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-102         [-1, 384, 128, 256]       24,576
# |    |    └─BatchNorm2d: 3-103                     [-1, 384, 128, 256]       768
# |    |    └─MemoryEfficientSwish: 3-104            [-1, 384, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-105         [-1, 384, 128, 256]       9,600
# |    |    └─BatchNorm2d: 3-106                     [-1, 384, 128, 256]       768
# |    |    └─MemoryEfficientSwish: 3-107            [-1, 384, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-108         [-1, 16, 1, 1]            6,160
# |    |    └─MemoryEfficientSwish: 3-109            [-1, 16, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-110         [-1, 384, 1, 1]           6,528
# |    |    └─Conv2dStaticSamePadding: 3-111         [-1, 64, 128, 256]        24,576
# |    |    └─BatchNorm2d: 3-112                     [-1, 64, 128, 256]        128
# |    └─MBConvBlock: 2-13                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-113         [-1, 384, 128, 256]       24,576
# |    |    └─BatchNorm2d: 3-114                     [-1, 384, 128, 256]       768
# |    |    └─MemoryEfficientSwish: 3-115            [-1, 384, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-116         [-1, 384, 128, 256]       9,600
# |    |    └─BatchNorm2d: 3-117                     [-1, 384, 128, 256]       768
# |    |    └─MemoryEfficientSwish: 3-118            [-1, 384, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-119         [-1, 16, 1, 1]            6,160
# |    |    └─MemoryEfficientSwish: 3-120            [-1, 16, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-121         [-1, 384, 1, 1]           6,528
# |    |    └─Conv2dStaticSamePadding: 3-122         [-1, 64, 128, 256]        24,576
# |    |    └─BatchNorm2d: 3-123                     [-1, 64, 128, 256]        128
# |    └─MBConvBlock: 2-14                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-124         [-1, 384, 128, 256]       24,576
# |    |    └─BatchNorm2d: 3-125                     [-1, 384, 128, 256]       768
# |    |    └─MemoryEfficientSwish: 3-126            [-1, 384, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-127         [-1, 384, 128, 256]       9,600
# |    |    └─BatchNorm2d: 3-128                     [-1, 384, 128, 256]       768
# |    |    └─MemoryEfficientSwish: 3-129            [-1, 384, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-130         [-1, 16, 1, 1]            6,160
# |    |    └─MemoryEfficientSwish: 3-131            [-1, 16, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-132         [-1, 384, 1, 1]           6,528
# |    |    └─Conv2dStaticSamePadding: 3-133         [-1, 64, 128, 256]        24,576
# |    |    └─BatchNorm2d: 3-134                     [-1, 64, 128, 256]        128
# |    └─MBConvBlock: 2-15                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-135         [-1, 384, 128, 256]       24,576
# |    |    └─BatchNorm2d: 3-136                     [-1, 384, 128, 256]       768
# |    |    └─MemoryEfficientSwish: 3-137            [-1, 384, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-138         [-1, 384, 64, 128]        3,456
# |    |    └─BatchNorm2d: 3-139                     [-1, 384, 64, 128]        768
# |    |    └─MemoryEfficientSwish: 3-140            [-1, 384, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-141         [-1, 16, 1, 1]            6,160
# |    |    └─MemoryEfficientSwish: 3-142            [-1, 16, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-143         [-1, 384, 1, 1]           6,528
# |    |    └─Conv2dStaticSamePadding: 3-144         [-1, 128, 64, 128]        49,152
# |    |    └─BatchNorm2d: 3-145                     [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-16                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-146         [-1, 768, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-147                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-148            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-149         [-1, 768, 64, 128]        6,912
# |    |    └─BatchNorm2d: 3-150                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-151            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-152         [-1, 32, 1, 1]            24,608
# |    |    └─MemoryEfficientSwish: 3-153            [-1, 32, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-154         [-1, 768, 1, 1]           25,344
# |    |    └─Conv2dStaticSamePadding: 3-155         [-1, 128, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-156                     [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-17                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-157         [-1, 768, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-158                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-159            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-160         [-1, 768, 64, 128]        6,912
# |    |    └─BatchNorm2d: 3-161                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-162            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-163         [-1, 32, 1, 1]            24,608
# |    |    └─MemoryEfficientSwish: 3-164            [-1, 32, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-165         [-1, 768, 1, 1]           25,344
# |    |    └─Conv2dStaticSamePadding: 3-166         [-1, 128, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-167                     [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-18                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-168         [-1, 768, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-169                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-170            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-171         [-1, 768, 64, 128]        6,912
# |    |    └─BatchNorm2d: 3-172                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-173            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-174         [-1, 32, 1, 1]            24,608
# |    |    └─MemoryEfficientSwish: 3-175            [-1, 32, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-176         [-1, 768, 1, 1]           25,344
# |    |    └─Conv2dStaticSamePadding: 3-177         [-1, 128, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-178                     [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-19                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-179         [-1, 768, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-180                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-181            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-182         [-1, 768, 64, 128]        6,912
# |    |    └─BatchNorm2d: 3-183                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-184            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-185         [-1, 32, 1, 1]            24,608
# |    |    └─MemoryEfficientSwish: 3-186            [-1, 32, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-187         [-1, 768, 1, 1]           25,344
# |    |    └─Conv2dStaticSamePadding: 3-188         [-1, 128, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-189                     [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-20                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-190         [-1, 768, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-191                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-192            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-193         [-1, 768, 64, 128]        6,912
# |    |    └─BatchNorm2d: 3-194                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-195            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-196         [-1, 32, 1, 1]            24,608
# |    |    └─MemoryEfficientSwish: 3-197            [-1, 32, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-198         [-1, 768, 1, 1]           25,344
# |    |    └─Conv2dStaticSamePadding: 3-199         [-1, 128, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-200                     [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-21                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-201         [-1, 768, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-202                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-203            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-204         [-1, 768, 64, 128]        6,912
# |    |    └─BatchNorm2d: 3-205                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-206            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-207         [-1, 32, 1, 1]            24,608
# |    |    └─MemoryEfficientSwish: 3-208            [-1, 32, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-209         [-1, 768, 1, 1]           25,344
# |    |    └─Conv2dStaticSamePadding: 3-210         [-1, 128, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-211                     [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-22                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-212         [-1, 768, 64, 128]        98,304
# |    |    └─BatchNorm2d: 3-213                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-214            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-215         [-1, 768, 64, 128]        19,200
# |    |    └─BatchNorm2d: 3-216                     [-1, 768, 64, 128]        1,536
# |    |    └─MemoryEfficientSwish: 3-217            [-1, 768, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-218         [-1, 32, 1, 1]            24,608
# |    |    └─MemoryEfficientSwish: 3-219            [-1, 32, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-220         [-1, 768, 1, 1]           25,344
# |    |    └─Conv2dStaticSamePadding: 3-221         [-1, 176, 64, 128]        135,168
# |    |    └─BatchNorm2d: 3-222                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-23                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-223         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-224                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-225            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-226         [-1, 1056, 64, 128]       26,400
# |    |    └─BatchNorm2d: 3-227                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-228            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-229         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-230            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-231         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-232         [-1, 176, 64, 128]        185,856
# |    |    └─BatchNorm2d: 3-233                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-24                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-234         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-235                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-236            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-237         [-1, 1056, 64, 128]       26,400
# |    |    └─BatchNorm2d: 3-238                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-239            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-240         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-241            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-242         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-243         [-1, 176, 64, 128]        185,856
# |    |    └─BatchNorm2d: 3-244                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-25                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-245         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-246                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-247            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-248         [-1, 1056, 64, 128]       26,400
# |    |    └─BatchNorm2d: 3-249                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-250            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-251         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-252            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-253         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-254         [-1, 176, 64, 128]        185,856
# |    |    └─BatchNorm2d: 3-255                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-26                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-256         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-257                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-258            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-259         [-1, 1056, 64, 128]       26,400
# |    |    └─BatchNorm2d: 3-260                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-261            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-262         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-263            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-264         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-265         [-1, 176, 64, 128]        185,856
# |    |    └─BatchNorm2d: 3-266                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-27                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-267         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-268                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-269            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-270         [-1, 1056, 64, 128]       26,400
# |    |    └─BatchNorm2d: 3-271                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-272            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-273         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-274            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-275         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-276         [-1, 176, 64, 128]        185,856
# |    |    └─BatchNorm2d: 3-277                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-28                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-278         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-279                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-280            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-281         [-1, 1056, 64, 128]       26,400
# |    |    └─BatchNorm2d: 3-282                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-283            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-284         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-285            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-286         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-287         [-1, 176, 64, 128]        185,856
# |    |    └─BatchNorm2d: 3-288                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-29                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-289         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-290                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-291            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-292         [-1, 1056, 32, 64]        26,400
# |    |    └─BatchNorm2d: 3-293                     [-1, 1056, 32, 64]        2,112
# |    |    └─MemoryEfficientSwish: 3-294            [-1, 1056, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-295         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-296            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-297         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-298         [-1, 304, 32, 64]         321,024
# |    |    └─BatchNorm2d: 3-299                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-30                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-300         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-301                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-302            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-303         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-304                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-305            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-306         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-307            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-308         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-309         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-310                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-31                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-311         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-312                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-313            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-314         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-315                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-316            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-317         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-318            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-319         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-320         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-321                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-32                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-322         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-323                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-324            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-325         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-326                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-327            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-328         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-329            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-330         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-331         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-332                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-33                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-333         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-334                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-335            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-336         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-337                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-338            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-339         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-340            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-341         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-342         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-343                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-34                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-344         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-345                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-346            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-347         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-348                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-349            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-350         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-351            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-352         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-353         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-354                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-35                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-355         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-356                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-357            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-358         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-359                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-360            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-361         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-362            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-363         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-364         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-365                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-36                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-366         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-367                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-368            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-369         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-370                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-371            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-372         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-373            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-374         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-375         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-376                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-37                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-377         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-378                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-379            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-380         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-381                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-382            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-383         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-384            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-385         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-386         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-387                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-38                           [-1, 512, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-388         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-389                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-390            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-391         [-1, 1824, 32, 64]        16,416
# |    |    └─BatchNorm2d: 3-392                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-393            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-394         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-395            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-396         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-397         [-1, 512, 32, 64]         933,888
# |    |    └─BatchNorm2d: 3-398                     [-1, 512, 32, 64]         1,024
# |    └─MBConvBlock: 2-39                           [-1, 512, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-399         [-1, 3072, 32, 64]        1,572,864
# |    |    └─BatchNorm2d: 3-400                     [-1, 3072, 32, 64]        6,144
# |    |    └─MemoryEfficientSwish: 3-401            [-1, 3072, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-402         [-1, 3072, 32, 64]        27,648
# |    |    └─BatchNorm2d: 3-403                     [-1, 3072, 32, 64]        6,144
# |    |    └─MemoryEfficientSwish: 3-404            [-1, 3072, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-405         [-1, 128, 1, 1]           393,344
# |    |    └─MemoryEfficientSwish: 3-406            [-1, 128, 1, 1]           --
# |    |    └─Conv2dStaticSamePadding: 3-407         [-1, 3072, 1, 1]          396,288
# |    |    └─Conv2dStaticSamePadding: 3-408         [-1, 512, 32, 64]         1,572,864
# |    |    └─BatchNorm2d: 3-409                     [-1, 512, 32, 64]         1,024
# |    └─MBConvBlock: 2-40                           [-1, 512, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-410         [-1, 3072, 32, 64]        1,572,864
# |    |    └─BatchNorm2d: 3-411                     [-1, 3072, 32, 64]        6,144
# |    |    └─MemoryEfficientSwish: 3-412            [-1, 3072, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-413         [-1, 3072, 32, 64]        27,648
# |    |    └─BatchNorm2d: 3-414                     [-1, 3072, 32, 64]        6,144
# |    |    └─MemoryEfficientSwish: 3-415            [-1, 3072, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-416         [-1, 128, 1, 1]           393,344
# |    |    └─MemoryEfficientSwish: 3-417            [-1, 128, 1, 1]           --
# |    |    └─Conv2dStaticSamePadding: 3-418         [-1, 3072, 1, 1]          396,288
# |    |    └─Conv2dStaticSamePadding: 3-419         [-1, 512, 32, 64]         1,572,864
# |    |    └─BatchNorm2d: 3-420                     [-1, 512, 32, 64]         1,024
# |    └─Identity: 2-41                              [-1, 512, 32, 64]         --
# ├─BatchNorm2d: 1-5                                 [-1, 2048, 32, 64]        4,096
# ├─MemoryEfficientSwish: 1-6                        [-1, 2048, 32, 64]        --
# ├─AdaptiveAvgPool2d: 1-7                           [-1, 2048, 1, 1]          --
# ├─Dropout: 1-8                                     [-1, 2048]                --
# ├─Linear: 1-9                                      [-1, 1000]                2,049,000
# ====================================================================================================
# Total params: 29,339,912
# Trainable params: 29,339,912
# Non-trainable params: 0
# Total mult-adds (G): 98.23
# ----------------------------------------------------------------------------------------------------
# Input size (MB): 24.00
# Forward/backward pass size (MB): 7455.26
# Params size (MB): 111.92
# Estimated Total Size (MB): 7591.18
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# ├─Conv2dStaticSamePadding: 1-1                     [-1, 48, 512, 1024]       --
# |    └─ZeroPad2d: 2-1                              [-1, 3, 1025, 2049]       --
# ├─BatchNorm2d: 1-2                                 [-1, 48, 512, 1024]       96
# ├─MemoryEfficientSwish: 1-3                        [-1, 48, 512, 1024]       --
# ├─Conv2dStaticSamePadding: 1-4                     [-1, 2048, 32, 64]        --
# |    └─MBConvBlock: 2-2                            [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-1           [-1, 48, 512, 1024]       432
# |    |    └─BatchNorm2d: 3-2                       [-1, 48, 512, 1024]       96
# |    |    └─MemoryEfficientSwish: 3-3              [-1, 48, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-4           [-1, 12, 1, 1]            588
# |    |    └─MemoryEfficientSwish: 3-5              [-1, 12, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-6           [-1, 48, 1, 1]            624
# |    |    └─Conv2dStaticSamePadding: 3-7           [-1, 24, 512, 1024]       1,152
# |    |    └─BatchNorm2d: 3-8                       [-1, 24, 512, 1024]       48
# |    └─MBConvBlock: 2-3                            [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-9           [-1, 24, 512, 1024]       216
# |    |    └─BatchNorm2d: 3-10                      [-1, 24, 512, 1024]       48
# |    |    └─MemoryEfficientSwish: 3-11             [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-12          [-1, 6, 1, 1]             150
# |    |    └─MemoryEfficientSwish: 3-13             [-1, 6, 1, 1]             --
# |    |    └─Conv2dStaticSamePadding: 3-14          [-1, 24, 1, 1]            168
# |    |    └─Conv2dStaticSamePadding: 3-15          [-1, 24, 512, 1024]       576
# |    |    └─BatchNorm2d: 3-16                      [-1, 24, 512, 1024]       48
# |    └─MBConvBlock: 2-4                            [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-17          [-1, 24, 512, 1024]       216
# |    |    └─BatchNorm2d: 3-18                      [-1, 24, 512, 1024]       48
# |    |    └─MemoryEfficientSwish: 3-19             [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-20          [-1, 6, 1, 1]             150
# |    |    └─MemoryEfficientSwish: 3-21             [-1, 6, 1, 1]             --
# |    |    └─Conv2dStaticSamePadding: 3-22          [-1, 24, 1, 1]            168
# |    |    └─Conv2dStaticSamePadding: 3-23          [-1, 24, 512, 1024]       576
# |    |    └─BatchNorm2d: 3-24                      [-1, 24, 512, 1024]       48
# |    └─MBConvBlock: 2-5                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-25          [-1, 144, 512, 1024]      3,456
# |    |    └─BatchNorm2d: 3-26                      [-1, 144, 512, 1024]      288
# |    |    └─MemoryEfficientSwish: 3-27             [-1, 144, 512, 1024]      --
# |    |    └─Conv2dStaticSamePadding: 3-28          [-1, 144, 256, 512]       1,296
# |    |    └─BatchNorm2d: 3-29                      [-1, 144, 256, 512]       288
# |    |    └─MemoryEfficientSwish: 3-30             [-1, 144, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-31          [-1, 6, 1, 1]             870
# |    |    └─MemoryEfficientSwish: 3-32             [-1, 6, 1, 1]             --
# |    |    └─Conv2dStaticSamePadding: 3-33          [-1, 144, 1, 1]           1,008
# |    |    └─Conv2dStaticSamePadding: 3-34          [-1, 40, 256, 512]        5,760
# |    |    └─BatchNorm2d: 3-35                      [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-6                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-36          [-1, 240, 256, 512]       9,600
# |    |    └─BatchNorm2d: 3-37                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-38             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-39          [-1, 240, 256, 512]       2,160
# |    |    └─BatchNorm2d: 3-40                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-41             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-42          [-1, 10, 1, 1]            2,410
# |    |    └─MemoryEfficientSwish: 3-43             [-1, 10, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-44          [-1, 240, 1, 1]           2,640
# |    |    └─Conv2dStaticSamePadding: 3-45          [-1, 40, 256, 512]        9,600
# |    |    └─BatchNorm2d: 3-46                      [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-7                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-47          [-1, 240, 256, 512]       9,600
# |    |    └─BatchNorm2d: 3-48                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-49             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-50          [-1, 240, 256, 512]       2,160
# |    |    └─BatchNorm2d: 3-51                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-52             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-53          [-1, 10, 1, 1]            2,410
# |    |    └─MemoryEfficientSwish: 3-54             [-1, 10, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-55          [-1, 240, 1, 1]           2,640
# |    |    └─Conv2dStaticSamePadding: 3-56          [-1, 40, 256, 512]        9,600
# |    |    └─BatchNorm2d: 3-57                      [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-8                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-58          [-1, 240, 256, 512]       9,600
# |    |    └─BatchNorm2d: 3-59                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-60             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-61          [-1, 240, 256, 512]       2,160
# |    |    └─BatchNorm2d: 3-62                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-63             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-64          [-1, 10, 1, 1]            2,410
# |    |    └─MemoryEfficientSwish: 3-65             [-1, 10, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-66          [-1, 240, 1, 1]           2,640
# |    |    └─Conv2dStaticSamePadding: 3-67          [-1, 40, 256, 512]        9,600
# |    |    └─BatchNorm2d: 3-68                      [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-9                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-69          [-1, 240, 256, 512]       9,600
# |    |    └─BatchNorm2d: 3-70                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-71             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-72          [-1, 240, 256, 512]       2,160
# |    |    └─BatchNorm2d: 3-73                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-74             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-75          [-1, 10, 1, 1]            2,410
# |    |    └─MemoryEfficientSwish: 3-76             [-1, 10, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-77          [-1, 240, 1, 1]           2,640
# |    |    └─Conv2dStaticSamePadding: 3-78          [-1, 40, 256, 512]        9,600
# |    |    └─BatchNorm2d: 3-79                      [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-10                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-80          [-1, 240, 256, 512]       9,600
# |    |    └─BatchNorm2d: 3-81                      [-1, 240, 256, 512]       480
# |    |    └─MemoryEfficientSwish: 3-82             [-1, 240, 256, 512]       --
# |    |    └─Conv2dStaticSamePadding: 3-83          [-1, 240, 128, 256]       6,000
# |    |    └─BatchNorm2d: 3-84                      [-1, 240, 128, 256]       480
# |    |    └─MemoryEfficientSwish: 3-85             [-1, 240, 128, 256]       --
# |    |    └─Conv2dStaticSamePadding: 3-86          [-1, 10, 1, 1]            2,410
# |    |    └─MemoryEfficientSwish: 3-87             [-1, 10, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-88          [-1, 240, 1, 1]           2,640
# ...
# |    |    └─BatchNorm2d: 3-255                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-26                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-256         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-257                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-258            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-259         [-1, 1056, 64, 128]       26,400
# |    |    └─BatchNorm2d: 3-260                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-261            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-262         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-263            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-264         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-265         [-1, 176, 64, 128]        185,856
# |    |    └─BatchNorm2d: 3-266                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-27                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-267         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-268                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-269            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-270         [-1, 1056, 64, 128]       26,400
# |    |    └─BatchNorm2d: 3-271                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-272            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-273         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-274            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-275         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-276         [-1, 176, 64, 128]        185,856
# |    |    └─BatchNorm2d: 3-277                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-28                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-278         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-279                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-280            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-281         [-1, 1056, 64, 128]       26,400
# |    |    └─BatchNorm2d: 3-282                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-283            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-284         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-285            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-286         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-287         [-1, 176, 64, 128]        185,856
# |    |    └─BatchNorm2d: 3-288                     [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-29                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-289         [-1, 1056, 64, 128]       185,856
# |    |    └─BatchNorm2d: 3-290                     [-1, 1056, 64, 128]       2,112
# |    |    └─MemoryEfficientSwish: 3-291            [-1, 1056, 64, 128]       --
# |    |    └─Conv2dStaticSamePadding: 3-292         [-1, 1056, 32, 64]        26,400
# |    |    └─BatchNorm2d: 3-293                     [-1, 1056, 32, 64]        2,112
# |    |    └─MemoryEfficientSwish: 3-294            [-1, 1056, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-295         [-1, 44, 1, 1]            46,508
# |    |    └─MemoryEfficientSwish: 3-296            [-1, 44, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-297         [-1, 1056, 1, 1]          47,520
# |    |    └─Conv2dStaticSamePadding: 3-298         [-1, 304, 32, 64]         321,024
# |    |    └─BatchNorm2d: 3-299                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-30                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-300         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-301                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-302            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-303         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-304                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-305            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-306         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-307            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-308         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-309         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-310                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-31                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-311         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-312                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-313            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-314         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-315                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-316            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-317         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-318            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-319         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-320         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-321                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-32                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-322         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-323                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-324            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-325         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-326                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-327            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-328         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-329            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-330         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-331         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-332                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-33                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-333         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-334                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-335            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-336         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-337                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-338            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-339         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-340            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-341         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-342         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-343                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-34                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-344         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-345                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-346            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-347         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-348                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-349            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-350         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-351            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-352         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-353         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-354                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-35                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-355         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-356                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-357            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-358         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-359                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-360            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-361         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-362            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-363         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-364         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-365                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-36                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-366         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-367                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-368            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-369         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-370                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-371            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-372         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-373            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-374         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-375         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-376                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-37                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-377         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-378                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-379            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-380         [-1, 1824, 32, 64]        45,600
# |    |    └─BatchNorm2d: 3-381                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-382            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-383         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-384            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-385         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-386         [-1, 304, 32, 64]         554,496
# |    |    └─BatchNorm2d: 3-387                     [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-38                           [-1, 512, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-388         [-1, 1824, 32, 64]        554,496
# |    |    └─BatchNorm2d: 3-389                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-390            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-391         [-1, 1824, 32, 64]        16,416
# |    |    └─BatchNorm2d: 3-392                     [-1, 1824, 32, 64]        3,648
# |    |    └─MemoryEfficientSwish: 3-393            [-1, 1824, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-394         [-1, 76, 1, 1]            138,700
# |    |    └─MemoryEfficientSwish: 3-395            [-1, 76, 1, 1]            --
# |    |    └─Conv2dStaticSamePadding: 3-396         [-1, 1824, 1, 1]          140,448
# |    |    └─Conv2dStaticSamePadding: 3-397         [-1, 512, 32, 64]         933,888
# |    |    └─BatchNorm2d: 3-398                     [-1, 512, 32, 64]         1,024
# |    └─MBConvBlock: 2-39                           [-1, 512, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-399         [-1, 3072, 32, 64]        1,572,864
# |    |    └─BatchNorm2d: 3-400                     [-1, 3072, 32, 64]        6,144
# |    |    └─MemoryEfficientSwish: 3-401            [-1, 3072, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-402         [-1, 3072, 32, 64]        27,648
# |    |    └─BatchNorm2d: 3-403                     [-1, 3072, 32, 64]        6,144
# |    |    └─MemoryEfficientSwish: 3-404            [-1, 3072, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-405         [-1, 128, 1, 1]           393,344
# |    |    └─MemoryEfficientSwish: 3-406            [-1, 128, 1, 1]           --
# |    |    └─Conv2dStaticSamePadding: 3-407         [-1, 3072, 1, 1]          396,288
# |    |    └─Conv2dStaticSamePadding: 3-408         [-1, 512, 32, 64]         1,572,864
# |    |    └─BatchNorm2d: 3-409                     [-1, 512, 32, 64]         1,024
# |    └─MBConvBlock: 2-40                           [-1, 512, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-410         [-1, 3072, 32, 64]        1,572,864
# |    |    └─BatchNorm2d: 3-411                     [-1, 3072, 32, 64]        6,144
# |    |    └─MemoryEfficientSwish: 3-412            [-1, 3072, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-413         [-1, 3072, 32, 64]        27,648
# |    |    └─BatchNorm2d: 3-414                     [-1, 3072, 32, 64]        6,144
# |    |    └─MemoryEfficientSwish: 3-415            [-1, 3072, 32, 64]        --
# |    |    └─Conv2dStaticSamePadding: 3-416         [-1, 128, 1, 1]           393,344
# |    |    └─MemoryEfficientSwish: 3-417            [-1, 128, 1, 1]           --
# |    |    └─Conv2dStaticSamePadding: 3-418         [-1, 3072, 1, 1]          396,288
# |    |    └─Conv2dStaticSamePadding: 3-419         [-1, 512, 32, 64]         1,572,864
# |    |    └─BatchNorm2d: 3-420                     [-1, 512, 32, 64]         1,024
# |    └─Identity: 2-41                              [-1, 512, 32, 64]         --
# ├─BatchNorm2d: 1-5                                 [-1, 2048, 32, 64]        4,096
# ├─MemoryEfficientSwish: 1-6                        [-1, 2048, 32, 64]        --
# ├─AdaptiveAvgPool2d: 1-7                           [-1, 2048, 1, 1]          --
# ├─Dropout: 1-8                                     [-1, 2048]                --
# ├─Linear: 1-9                                      [-1, 1000]                2,049,000
# ====================================================================================================
# Total params: 29,339,912
# Trainable params: 29,339,912
# Non-trainable params: 0
# Total mult-adds (G): 98.23
# ----------------------------------------------------------------------------------------------------
# Input size (MB): 24.00
# Forward/backward pass size (MB): 7455.26
# Params size (MB): 111.92
# Estimated Total Size (MB): 7591.18
# ----------------------------------------------------------------------------------------------------

# %%
import torch
from torch import nn
from torch.nn import functional as F
from inplace_abn.abn import InPlaceABN

from efficientnet_pytorch.utils import (
    round_filters,
    round_repeats,
    drop_connect,
    get_same_padding_conv2d,
    get_model_params,
    efficientnet_params,
    load_pretrained_weights,
    Swish,
    MemoryEfficientSwish,
)

class MBConvBlock(nn.Module):
    """
    Mobile Inverted Residual Bottleneck Block

    Args:
        block_args (namedtuple): BlockArgs, see above
        global_params (namedtuple): GlobalParam, see above

    Attributes:
        has_se (bool): Whether the block contains a Squeeze and Excitation layer.
    """

    def __init__(self, block_args, global_params):
        super().__init__()
        self._block_args = block_args
        self._bn_mom = 1 - global_params.batch_norm_momentum
        self._bn_eps = global_params.batch_norm_epsilon
        self.has_se = (self._block_args.se_ratio is not None) and (0 < self._block_args.se_ratio <= 1)
        self.id_skip = block_args.id_skip  # skip connection and drop connect

        # Get static or dynamic convolution depending on image size
        Conv2d = get_same_padding_conv2d(image_size=global_params.image_size)

        # Expansion phase
        inp = self._block_args.input_filters  # number of input channels
        oup = self._block_args.input_filters * self._block_args.expand_ratio  # number of output channels
        if self._block_args.expand_ratio != 1:
            self._expand_conv = Conv2d(in_channels=inp, out_channels=oup, kernel_size=1, bias=False)
            self._bn0 = InPlaceABN(oup)

        # Depthwise convolution phase
        k = self._block_args.kernel_size
        s = self._block_args.stride
        self._depthwise_conv = Conv2d(
            in_channels=oup, out_channels=oup, groups=oup,  # groups makes it depthwise
            kernel_size=k, stride=s, bias=False)
        self._bn1 = InPlaceABN(oup)

        # Squeeze and Excitation layer, if desired

        ## Deleted it from here


        # Output phase
        final_oup = self._block_args.output_filters
        self._project_conv = Conv2d(in_channels=oup, out_channels=final_oup, kernel_size=1, bias=False)
        self._bn2 = InPlaceABN(final_oup)

    def forward(self, inputs, drop_connect_rate=None):
        """
        :param inputs: input tensor
        :param drop_connect_rate: drop connect rate (float, between 0 and 1)
        :return: output of block
        """

        # Expansion and Depthwise Convolution
        x = inputs
        if self._block_args.expand_ratio != 1:
            x = self._bn0(self._expand_conv(inputs))
        x = self._bn1(self._depthwise_conv(x))

        # Squeeze and Excitation
        # Delete SE layer from here


        x = self._bn2(self._project_conv(x))

        # Skip connection and drop connect
        input_filters, output_filters = self._block_args.input_filters, self._block_args.output_filters
        if self.id_skip and self._block_args.stride == 1 and input_filters == output_filters:
            if drop_connect_rate:
                x = drop_connect(x, p=drop_connect_rate, training=self.training)
            x = x + inputs  # skip connection
        return x




class EfficientNet(nn.Module):
    """
    An EfficientNet model. Most easily loaded with the .from_name or .from_pretrained methods

    Args:
        blocks_args (list): A list of BlockArgs to construct blocks
        global_params (namedtuple): A set of GlobalParams shared between blocks

    Example:
        model = EfficientNet.from_pretrained('efficientnet-b0')

    """

    def __init__(self, blocks_args=None, global_params=None):
        super().__init__()
        assert isinstance(blocks_args, list), 'blocks_args should be a list'
        assert len(blocks_args) > 0, 'block args must be greater than 0'
        self._global_params = global_params
        self._blocks_args = blocks_args

        # Get static or dynamic convolution depending on image size
        Conv2d = get_same_padding_conv2d(image_size=global_params.image_size)

        # Batch norm parameters
        bn_mom = 1 - self._global_params.batch_norm_momentum
        bn_eps = self._global_params.batch_norm_epsilon

        # Stem
        in_channels = 3  # rgb
        out_channels = round_filters(32, self._global_params)  # number of output channels
        self._conv_stem = Conv2d(in_channels, out_channels, kernel_size=3, stride=2, bias=False)
        self._bn0 = InPlaceABN(out_channels)

        # Build blocks
        self._blocks = nn.ModuleList([])

        for block_args in self._blocks_args:

            # Update block input and output filters based on depth multiplier.
            block_args = block_args._replace(
                input_filters=round_filters(block_args.input_filters, self._global_params),
                output_filters=round_filters(block_args.output_filters, self._global_params),
                num_repeat=round_repeats(block_args.num_repeat, self._global_params)
            )

            # The first block needs to take care of stride and filter size increase.
            self._blocks.append(MBConvBlock(block_args, self._global_params))
            if block_args.num_repeat > 1:
                block_args = block_args._replace(input_filters=block_args.output_filters, stride=1)
            for _ in range(block_args.num_repeat - 1):
                self._blocks.append(MBConvBlock(block_args, self._global_params))


        # Head
        in_channels = block_args.output_filters  # output of final block
        out_channels = round_filters(1280, self._global_params)
        self._conv_head = Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self._bn1 = InPlaceABN(out_channels)


    def extract_features(self, inputs):
        """ Returns output of the final convolution layer """

        # Stem
        x = self._bn0(self._conv_stem(inputs))

        # Blocks
        for idx, block in enumerate(self._blocks):
            drop_connect_rate = self._global_params.drop_connect_rate
            if drop_connect_rate:
                drop_connect_rate *= float(idx) / len(self._blocks)
            x = block(x, drop_connect_rate=drop_connect_rate)
            


        # Head
        x = self._bn1(self._conv_head(x))
        #self.arr.append(x)
        return x

    def forward(self, inputs):
        """ Calls extract_features to extract features, applies final linear layer, and returns logits. """
        bs = inputs.size(0)
        # Convolution layers
        x = self.extract_features(inputs)

        return x

    @classmethod
    def from_name(cls, model_name, override_params=None):
        cls._check_model_name_is_valid(model_name)
        blocks_args, global_params = get_model_params(model_name, override_params)
        return cls(blocks_args, global_params)

    @classmethod
    def from_pretrained(cls, model_name, advprop=False, num_classes=1000, in_channels=3):
        model = cls.from_name(model_name, override_params={'num_classes': num_classes})
        load_pretrained_weights(model, model_name, load_fc=(num_classes == 1000), advprop=advprop)
        if in_channels != 3:
            Conv2d = get_same_padding_conv2d(image_size = model._global_params.image_size)
            out_channels = round_filters(32, model._global_params)
            model._conv_stem = Conv2d(in_channels, out_channels, kernel_size=3, stride=2, bias=False)
        return model
    
    @classmethod
    def get_image_size(cls, model_name):
        cls._check_model_name_is_valid(model_name)
        _, _, res, _ = efficientnet_params(model_name)
        return res

    @classmethod
    def _check_model_name_is_valid(cls, model_name):
        """ Validates model name. """ 
        valid_models = ['efficientnet-b'+str(i) for i in range(9)]
        if model_name not in valid_models:
            raise ValueError('model_name should be one of: ' + ', '.join(valid_models))

    def return_sub(self):
      return self._blocks

# %%
model = EfficientNet(x[0],x[1])

# %%
arr = model.return_sub()

# %%
model
# Out:
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 48, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   )
#   (_bn0): InPlaceABN(48, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         48, 48, kernel_size=(3, 3), stride=[1, 1], groups=48, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(48, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(24, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(24, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(24, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (2): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(24, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(24, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(144, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(144, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(40, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(40, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(40, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(40, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(40, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(5, 5), stride=[2, 2], groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(64, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(64, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(64, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(64, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(64, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         384, 384, kernel_size=(3, 3), stride=[2, 2], groups=384, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         768, 768, kernel_size=(5, 5), stride=[1, 1], groups=768, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         768, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (23): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (24): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (25): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (26): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (27): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1056, 1056, kernel_size=(5, 5), stride=[2, 2], groups=1056, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1056, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (28): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (29): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (30): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (31): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (32): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (33): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (34): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (35): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (36): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1824, 1824, kernel_size=(3, 3), stride=[1, 1], groups=1824, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         1824, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(512, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (37): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(3072, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         3072, 3072, kernel_size=(3, 3), stride=(1, 1), groups=3072, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(3072, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(512, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#     (38): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): InPlaceABN(3072, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         3072, 3072, kernel_size=(3, 3), stride=(1, 1), groups=3072, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): InPlaceABN(3072, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#       (_project_conv): Conv2dStaticSamePadding(
#         3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): InPlaceABN(512, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): InPlaceABN(2048, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
# )

# %%
arr
# Out:
# [MBConvBlock(
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(64, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(64, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(64, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(64, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(128, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(128, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(128, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(128, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(128, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(768, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(128, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(176, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(176, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(176, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(176, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(176, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1056, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(176, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#      (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#    )
#    (_bn1): BatchNorm2d(1824, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(3072, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      3072, 3072, kernel_size=(3, 3), stride=(1, 1), groups=3072, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(3072, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(512, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  ), MBConvBlock(
#    (_expand_conv): Conv2dStaticSamePadding(
#      512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn0): BatchNorm2d(3072, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_depthwise_conv): Conv2dStaticSamePadding(
#      3072, 3072, kernel_size=(3, 3), stride=(1, 1), groups=3072, bias=False
#      (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#    )
#    (_bn1): BatchNorm2d(3072, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_project_conv): Conv2dStaticSamePadding(
#      3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#      (static_padding): Identity()
#    )
#    (_bn2): BatchNorm2d(512, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#    (_swish): MemoryEfficientSwish()
#  )]

# %%
import torch
from torchsummary import summary

sum = summary(model, torch.zeros((1, 3, 1024, 2048)))
#print(summary(model, torch.zeros((1, 3, 1024, 2048)), show_input=True, show_hierarchical=True))
# Out:
# ----------------------------------------------------------------------------------------------------
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# ├─Conv2dStaticSamePadding: 1-1                     [-1, 48, 512, 1024]       --
# |    └─ZeroPad2d: 2-1                              [-1, 3, 1025, 2049]       --
# ├─InPlaceABN: 1-2                                  [-1, 48, 512, 1024]       96
# ├─Conv2dStaticSamePadding: 1-3                     [-1, 2048, 32, 64]        --
# |    └─MBConvBlock: 2-2                            [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-1           [-1, 48, 512, 1024]       432
# |    |    └─InPlaceABN: 3-2                        [-1, 48, 512, 1024]       96
# |    |    └─Conv2dStaticSamePadding: 3-3           [-1, 24, 512, 1024]       1,152
# |    |    └─InPlaceABN: 3-4                        [-1, 24, 512, 1024]       48
# |    └─MBConvBlock: 2-3                            [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-5           [-1, 24, 512, 1024]       216
# |    |    └─InPlaceABN: 3-6                        [-1, 24, 512, 1024]       48
# |    |    └─Conv2dStaticSamePadding: 3-7           [-1, 24, 512, 1024]       576
# |    |    └─InPlaceABN: 3-8                        [-1, 24, 512, 1024]       48
# |    └─MBConvBlock: 2-4                            [-1, 24, 512, 1024]       --
# |    |    └─Conv2dStaticSamePadding: 3-9           [-1, 24, 512, 1024]       216
# |    |    └─InPlaceABN: 3-10                       [-1, 24, 512, 1024]       48
# |    |    └─Conv2dStaticSamePadding: 3-11          [-1, 24, 512, 1024]       576
# |    |    └─InPlaceABN: 3-12                       [-1, 24, 512, 1024]       48
# |    └─MBConvBlock: 2-5                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-13          [-1, 144, 512, 1024]      3,456
# |    |    └─InPlaceABN: 3-14                       [-1, 144, 512, 1024]      288
# |    |    └─Conv2dStaticSamePadding: 3-15          [-1, 144, 256, 512]       1,296
# |    |    └─InPlaceABN: 3-16                       [-1, 144, 256, 512]       288
# |    |    └─Conv2dStaticSamePadding: 3-17          [-1, 40, 256, 512]        5,760
# |    |    └─InPlaceABN: 3-18                       [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-6                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-19          [-1, 240, 256, 512]       9,600
# |    |    └─InPlaceABN: 3-20                       [-1, 240, 256, 512]       480
# |    |    └─Conv2dStaticSamePadding: 3-21          [-1, 240, 256, 512]       2,160
# |    |    └─InPlaceABN: 3-22                       [-1, 240, 256, 512]       480
# |    |    └─Conv2dStaticSamePadding: 3-23          [-1, 40, 256, 512]        9,600
# |    |    └─InPlaceABN: 3-24                       [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-7                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-25          [-1, 240, 256, 512]       9,600
# |    |    └─InPlaceABN: 3-26                       [-1, 240, 256, 512]       480
# |    |    └─Conv2dStaticSamePadding: 3-27          [-1, 240, 256, 512]       2,160
# |    |    └─InPlaceABN: 3-28                       [-1, 240, 256, 512]       480
# |    |    └─Conv2dStaticSamePadding: 3-29          [-1, 40, 256, 512]        9,600
# |    |    └─InPlaceABN: 3-30                       [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-8                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-31          [-1, 240, 256, 512]       9,600
# |    |    └─InPlaceABN: 3-32                       [-1, 240, 256, 512]       480
# |    |    └─Conv2dStaticSamePadding: 3-33          [-1, 240, 256, 512]       2,160
# |    |    └─InPlaceABN: 3-34                       [-1, 240, 256, 512]       480
# |    |    └─Conv2dStaticSamePadding: 3-35          [-1, 40, 256, 512]        9,600
# |    |    └─InPlaceABN: 3-36                       [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-9                            [-1, 40, 256, 512]        --
# |    |    └─Conv2dStaticSamePadding: 3-37          [-1, 240, 256, 512]       9,600
# |    |    └─InPlaceABN: 3-38                       [-1, 240, 256, 512]       480
# |    |    └─Conv2dStaticSamePadding: 3-39          [-1, 240, 256, 512]       2,160
# |    |    └─InPlaceABN: 3-40                       [-1, 240, 256, 512]       480
# |    |    └─Conv2dStaticSamePadding: 3-41          [-1, 40, 256, 512]        9,600
# |    |    └─InPlaceABN: 3-42                       [-1, 40, 256, 512]        80
# |    └─MBConvBlock: 2-10                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-43          [-1, 240, 256, 512]       9,600
# |    |    └─InPlaceABN: 3-44                       [-1, 240, 256, 512]       480
# |    |    └─Conv2dStaticSamePadding: 3-45          [-1, 240, 128, 256]       6,000
# |    |    └─InPlaceABN: 3-46                       [-1, 240, 128, 256]       480
# |    |    └─Conv2dStaticSamePadding: 3-47          [-1, 64, 128, 256]        15,360
# |    |    └─InPlaceABN: 3-48                       [-1, 64, 128, 256]        128
# |    └─MBConvBlock: 2-11                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-49          [-1, 384, 128, 256]       24,576
# |    |    └─InPlaceABN: 3-50                       [-1, 384, 128, 256]       768
# |    |    └─Conv2dStaticSamePadding: 3-51          [-1, 384, 128, 256]       9,600
# |    |    └─InPlaceABN: 3-52                       [-1, 384, 128, 256]       768
# |    |    └─Conv2dStaticSamePadding: 3-53          [-1, 64, 128, 256]        24,576
# |    |    └─InPlaceABN: 3-54                       [-1, 64, 128, 256]        128
# |    └─MBConvBlock: 2-12                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-55          [-1, 384, 128, 256]       24,576
# |    |    └─InPlaceABN: 3-56                       [-1, 384, 128, 256]       768
# |    |    └─Conv2dStaticSamePadding: 3-57          [-1, 384, 128, 256]       9,600
# |    |    └─InPlaceABN: 3-58                       [-1, 384, 128, 256]       768
# |    |    └─Conv2dStaticSamePadding: 3-59          [-1, 64, 128, 256]        24,576
# |    |    └─InPlaceABN: 3-60                       [-1, 64, 128, 256]        128
# |    └─MBConvBlock: 2-13                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-61          [-1, 384, 128, 256]       24,576
# |    |    └─InPlaceABN: 3-62                       [-1, 384, 128, 256]       768
# |    |    └─Conv2dStaticSamePadding: 3-63          [-1, 384, 128, 256]       9,600
# |    |    └─InPlaceABN: 3-64                       [-1, 384, 128, 256]       768
# |    |    └─Conv2dStaticSamePadding: 3-65          [-1, 64, 128, 256]        24,576
# |    |    └─InPlaceABN: 3-66                       [-1, 64, 128, 256]        128
# |    └─MBConvBlock: 2-14                           [-1, 64, 128, 256]        --
# |    |    └─Conv2dStaticSamePadding: 3-67          [-1, 384, 128, 256]       24,576
# |    |    └─InPlaceABN: 3-68                       [-1, 384, 128, 256]       768
# |    |    └─Conv2dStaticSamePadding: 3-69          [-1, 384, 128, 256]       9,600
# |    |    └─InPlaceABN: 3-70                       [-1, 384, 128, 256]       768
# |    |    └─Conv2dStaticSamePadding: 3-71          [-1, 64, 128, 256]        24,576
# |    |    └─InPlaceABN: 3-72                       [-1, 64, 128, 256]        128
# |    └─MBConvBlock: 2-15                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-73          [-1, 384, 128, 256]       24,576
# |    |    └─InPlaceABN: 3-74                       [-1, 384, 128, 256]       768
# |    |    └─Conv2dStaticSamePadding: 3-75          [-1, 384, 64, 128]        3,456
# |    |    └─InPlaceABN: 3-76                       [-1, 384, 64, 128]        768
# |    |    └─Conv2dStaticSamePadding: 3-77          [-1, 128, 64, 128]        49,152
# |    |    └─InPlaceABN: 3-78                       [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-16                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-79          [-1, 768, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-80                       [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-81          [-1, 768, 64, 128]        6,912
# |    |    └─InPlaceABN: 3-82                       [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-83          [-1, 128, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-84                       [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-17                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-85          [-1, 768, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-86                       [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-87          [-1, 768, 64, 128]        6,912
# |    |    └─InPlaceABN: 3-88                       [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-89          [-1, 128, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-90                       [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-18                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-91          [-1, 768, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-92                       [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-93          [-1, 768, 64, 128]        6,912
# |    |    └─InPlaceABN: 3-94                       [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-95          [-1, 128, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-96                       [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-19                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-97          [-1, 768, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-98                       [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-99          [-1, 768, 64, 128]        6,912
# |    |    └─InPlaceABN: 3-100                      [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-101         [-1, 128, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-102                      [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-20                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-103         [-1, 768, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-104                      [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-105         [-1, 768, 64, 128]        6,912
# |    |    └─InPlaceABN: 3-106                      [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-107         [-1, 128, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-108                      [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-21                           [-1, 128, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-109         [-1, 768, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-110                      [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-111         [-1, 768, 64, 128]        6,912
# |    |    └─InPlaceABN: 3-112                      [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-113         [-1, 128, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-114                      [-1, 128, 64, 128]        256
# |    └─MBConvBlock: 2-22                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-115         [-1, 768, 64, 128]        98,304
# |    |    └─InPlaceABN: 3-116                      [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-117         [-1, 768, 64, 128]        19,200
# |    |    └─InPlaceABN: 3-118                      [-1, 768, 64, 128]        1,536
# |    |    └─Conv2dStaticSamePadding: 3-119         [-1, 176, 64, 128]        135,168
# |    |    └─InPlaceABN: 3-120                      [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-23                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-121         [-1, 1056, 64, 128]       185,856
# |    |    └─InPlaceABN: 3-122                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-123         [-1, 1056, 64, 128]       26,400
# |    |    └─InPlaceABN: 3-124                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-125         [-1, 176, 64, 128]        185,856
# |    |    └─InPlaceABN: 3-126                      [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-24                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-127         [-1, 1056, 64, 128]       185,856
# |    |    └─InPlaceABN: 3-128                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-129         [-1, 1056, 64, 128]       26,400
# |    |    └─InPlaceABN: 3-130                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-131         [-1, 176, 64, 128]        185,856
# |    |    └─InPlaceABN: 3-132                      [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-25                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-133         [-1, 1056, 64, 128]       185,856
# |    |    └─InPlaceABN: 3-134                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-135         [-1, 1056, 64, 128]       26,400
# |    |    └─InPlaceABN: 3-136                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-137         [-1, 176, 64, 128]        185,856
# |    |    └─InPlaceABN: 3-138                      [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-26                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-139         [-1, 1056, 64, 128]       185,856
# |    |    └─InPlaceABN: 3-140                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-141         [-1, 1056, 64, 128]       26,400
# |    |    └─InPlaceABN: 3-142                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-143         [-1, 176, 64, 128]        185,856
# |    |    └─InPlaceABN: 3-144                      [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-27                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-145         [-1, 1056, 64, 128]       185,856
# |    |    └─InPlaceABN: 3-146                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-147         [-1, 1056, 64, 128]       26,400
# |    |    └─InPlaceABN: 3-148                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-149         [-1, 176, 64, 128]        185,856
# |    |    └─InPlaceABN: 3-150                      [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-28                           [-1, 176, 64, 128]        --
# |    |    └─Conv2dStaticSamePadding: 3-151         [-1, 1056, 64, 128]       185,856
# |    |    └─InPlaceABN: 3-152                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-153         [-1, 1056, 64, 128]       26,400
# |    |    └─InPlaceABN: 3-154                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-155         [-1, 176, 64, 128]        185,856
# |    |    └─InPlaceABN: 3-156                      [-1, 176, 64, 128]        352
# |    └─MBConvBlock: 2-29                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-157         [-1, 1056, 64, 128]       185,856
# |    |    └─InPlaceABN: 3-158                      [-1, 1056, 64, 128]       2,112
# |    |    └─Conv2dStaticSamePadding: 3-159         [-1, 1056, 32, 64]        26,400
# |    |    └─InPlaceABN: 3-160                      [-1, 1056, 32, 64]        2,112
# |    |    └─Conv2dStaticSamePadding: 3-161         [-1, 304, 32, 64]         321,024
# |    |    └─InPlaceABN: 3-162                      [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-30                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-163         [-1, 1824, 32, 64]        554,496
# |    |    └─InPlaceABN: 3-164                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-165         [-1, 1824, 32, 64]        45,600
# |    |    └─InPlaceABN: 3-166                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-167         [-1, 304, 32, 64]         554,496
# |    |    └─InPlaceABN: 3-168                      [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-31                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-169         [-1, 1824, 32, 64]        554,496
# |    |    └─InPlaceABN: 3-170                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-171         [-1, 1824, 32, 64]        45,600
# |    |    └─InPlaceABN: 3-172                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-173         [-1, 304, 32, 64]         554,496
# |    |    └─InPlaceABN: 3-174                      [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-32                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-175         [-1, 1824, 32, 64]        554,496
# |    |    └─InPlaceABN: 3-176                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-177         [-1, 1824, 32, 64]        45,600
# |    |    └─InPlaceABN: 3-178                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-179         [-1, 304, 32, 64]         554,496
# |    |    └─InPlaceABN: 3-180                      [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-33                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-181         [-1, 1824, 32, 64]        554,496
# |    |    └─InPlaceABN: 3-182                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-183         [-1, 1824, 32, 64]        45,600
# |    |    └─InPlaceABN: 3-184                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-185         [-1, 304, 32, 64]         554,496
# |    |    └─InPlaceABN: 3-186                      [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-34                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-187         [-1, 1824, 32, 64]        554,496
# |    |    └─InPlaceABN: 3-188                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-189         [-1, 1824, 32, 64]        45,600
# |    |    └─InPlaceABN: 3-190                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-191         [-1, 304, 32, 64]         554,496
# |    |    └─InPlaceABN: 3-192                      [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-35                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-193         [-1, 1824, 32, 64]        554,496
# |    |    └─InPlaceABN: 3-194                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-195         [-1, 1824, 32, 64]        45,600
# |    |    └─InPlaceABN: 3-196                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-197         [-1, 304, 32, 64]         554,496
# |    |    └─InPlaceABN: 3-198                      [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-36                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-199         [-1, 1824, 32, 64]        554,496
# |    |    └─InPlaceABN: 3-200                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-201         [-1, 1824, 32, 64]        45,600
# |    |    └─InPlaceABN: 3-202                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-203         [-1, 304, 32, 64]         554,496
# |    |    └─InPlaceABN: 3-204                      [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-37                           [-1, 304, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-205         [-1, 1824, 32, 64]        554,496
# |    |    └─InPlaceABN: 3-206                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-207         [-1, 1824, 32, 64]        45,600
# |    |    └─InPlaceABN: 3-208                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-209         [-1, 304, 32, 64]         554,496
# |    |    └─InPlaceABN: 3-210                      [-1, 304, 32, 64]         608
# |    └─MBConvBlock: 2-38                           [-1, 512, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-211         [-1, 1824, 32, 64]        554,496
# |    |    └─InPlaceABN: 3-212                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-213         [-1, 1824, 32, 64]        16,416
# |    |    └─InPlaceABN: 3-214                      [-1, 1824, 32, 64]        3,648
# |    |    └─Conv2dStaticSamePadding: 3-215         [-1, 512, 32, 64]         933,888
# |    |    └─InPlaceABN: 3-216                      [-1, 512, 32, 64]         1,024
# |    └─MBConvBlock: 2-39                           [-1, 512, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-217         [-1, 3072, 32, 64]        1,572,864
# |    |    └─InPlaceABN: 3-218                      [-1, 3072, 32, 64]        6,144
# |    |    └─Conv2dStaticSamePadding: 3-219         [-1, 3072, 32, 64]        27,648
# |    |    └─InPlaceABN: 3-220                      [-1, 3072, 32, 64]        6,144
# |    |    └─Conv2dStaticSamePadding: 3-221         [-1, 512, 32, 64]         1,572,864
# |    |    └─InPlaceABN: 3-222                      [-1, 512, 32, 64]         1,024
# |    └─MBConvBlock: 2-40                           [-1, 512, 32, 64]         --
# |    |    └─Conv2dStaticSamePadding: 3-223         [-1, 3072, 32, 64]        1,572,864
# |    |    └─InPlaceABN: 3-224                      [-1, 3072, 32, 64]        6,144
# |    |    └─Conv2dStaticSamePadding: 3-225         [-1, 3072, 32, 64]        27,648
# |    |    └─InPlaceABN: 3-226                      [-1, 3072, 32, 64]        6,144
# |    |    └─Conv2dStaticSamePadding: 3-227         [-1, 512, 32, 64]         1,572,864
# |    |    └─InPlaceABN: 3-228                      [-1, 512, 32, 64]         1,024
# |    └─Identity: 2-41                              [-1, 512, 32, 64]         --
# ├─InPlaceABN: 1-4                                  [-1, 2048, 32, 64]        4,096
# ====================================================================================================
# Total params: 22,099,040
# Trainable params: 22,099,040
# Non-trainable params: 0
# Total mult-adds (G): 98.21
# ----------------------------------------------------------------------------------------------------
# Input size (MB): 24.00
# Forward/backward pass size (MB): 7455.25
# Params size (MB): 84.30
# Estimated Total Size (MB): 7563.55
# ----------------------------------------------------------------------------------------------------

# %%
out = model(torch.randn((1, 3, 1024, 2048)).to('cuda'))

# %%
out
# Out:
# tensor([[[[ 1.7473e-01, -2.3720e-06, -8.6524e-03,  ..., -9.0770e-03,
#             7.1543e-01,  1.3273e+00],
#           [ 1.7386e+00,  3.1725e-01,  2.7964e-01,  ...,  1.0822e+00,
#            -8.7940e-05, -8.5076e-04],
#           [ 5.6941e-01,  2.1081e-01, -6.9113e-03,  ..., -9.4085e-03,
#            -1.2389e-02,  3.0728e+00],
#           ...,
#           [-1.2073e-04,  4.3526e-01,  1.1212e+00,  ..., -6.4945e-03,
#             2.0077e-01,  3.5688e-01],
#           [ 5.2350e-01, -5.2866e-03, -1.3075e-02,  ..., -7.1414e-03,
#             7.6836e-01,  8.4422e-03],
#           [ 1.7307e+00,  1.9177e-01,  1.3171e+00,  ..., -2.1677e-03,
#             1.4745e+00,  6.1034e-01]],
#
#          [[-9.8656e-03,  1.0582e+00,  8.8826e-01,  ..., -1.0193e-02,
#             6.3557e-01,  9.7449e-01],
#           [-1.6288e-02, -2.0732e-03,  1.1458e+00,  ...,  5.2858e-01,
#            -1.4589e-02, -3.9106e-03],
#           [ 2.8597e-01,  6.8582e-01,  3.0464e-01,  ...,  1.4267e+00,
#             8.7797e-01,  9.9169e-01],
#           ...,
#           [-6.1078e-03, -1.4033e-02, -1.1243e-02,  ..., -1.1846e-02,
#            -1.2317e-02,  1.7326e+00],
#           [-1.0621e-02, -2.8902e-03, -1.1027e-02,  ...,  3.9594e-01,
#             2.3052e-01, -2.7985e-03],
#           [-7.4661e-03,  1.1795e-02,  1.1954e+00,  ...,  3.0009e-01,
#             5.3802e-01,  3.7057e-01]],
#
#          [[-5.7115e-03,  8.4283e-02, -7.6397e-03,  ..., -5.4497e-03,
#             4.7742e-01, -3.5372e-03],
#           [ 2.6809e-01,  2.5816e-01, -6.7333e-03,  ...,  1.1877e+00,
#            -1.6082e-02,  4.7306e-01],
#           [ 3.2839e-01,  5.9180e-01,  4.2296e-01,  ..., -5.1482e-04,
#            -4.9939e-03, -9.5617e-03],
#           ...,
#           [ 1.0541e+00,  1.3507e-01,  3.5737e-01,  ...,  1.5043e+00,
#            -4.7898e-03, -8.1772e-03],
#           [-5.7288e-04, -6.0626e-03, -5.0187e-03,  ...,  1.1162e+00,
#             1.3830e-01,  1.5900e+00],
#           [ 8.7286e-01, -5.0944e-03,  3.1322e-01,  ...,  8.1678e-01,
#             1.4154e+00, -6.5670e-03]],
#
#          ...,
#
#          [[-6.3841e-03,  5.5501e-01,  8.2399e-01,  ..., -9.8967e-03,
#            -6.2660e-03,  4.2526e-01],
#           [ 7.5357e-01,  2.9829e-01, -5.9118e-03,  ..., -5.1632e-03,
#            -4.6665e-04, -4.4154e-03],
#           [ 8.9880e-02,  1.0325e+00, -4.3923e-03,  ..., -2.2563e-04,
#            -1.1616e-02, -1.1009e-02],
#           ...,
#           [ 1.3923e+00,  7.5095e-01,  1.1579e+00,  ..., -1.1472e-02,
#             3.3289e-01,  1.3204e-01],
#           [ 1.1828e+00, -1.0089e-02,  8.9646e-01,  ...,  4.9837e-01,
#            -3.8847e-03, -4.9819e-03],
#           [ 1.8834e+00, -2.9692e-03,  3.7613e-02,  ..., -4.0006e-03,
#             3.8397e-01, -3.6765e-03]],
#
#          [[-7.4771e-03, -9.2633e-03, -1.3901e-02,  ..., -1.6644e-02,
#            -9.9112e-03,  5.3498e-01],
#           [-1.4242e-03,  6.1081e-01,  9.1586e-01,  ...,  3.4372e-01,
#            -3.1969e-03, -8.1218e-03],
#           [ 1.8381e-01, -4.5534e-03, -4.0358e-03,  ..., -1.2910e-02,
#             4.1796e-01, -1.0675e-02],
#           ...,
#           [ 4.3276e-01, -5.7760e-03, -1.1840e-03,  ...,  6.5991e-01,
#             8.5184e-01,  1.2432e-01],
#           [ 5.7255e-02, -8.9454e-03,  1.8368e-01,  ...,  4.2035e-01,
#             6.7150e-01,  1.1272e+00],
#           [ 1.2089e+00,  2.1285e-01,  1.8623e+00,  ..., -7.6081e-03,
#             1.5800e+00,  9.9744e-01]],
#
#          [[-2.3750e-03, -7.8692e-03, -4.0925e-03,  ..., -1.0403e-03,
#             9.6194e-01,  8.8164e-01],
#           [ 1.4654e-01,  6.3054e-01, -3.4935e-03,  ...,  2.6355e-01,
#            -1.8601e-02, -3.4771e-04],
#           [-1.1246e-02,  1.0665e+00, -2.7289e-03,  ...,  5.9252e-01,
#            -1.6381e-02, -5.1159e-04],
#           ...,
#           [-1.7650e-02,  1.1227e+00, -1.1214e-02,  ..., -1.7286e-03,
#            -9.4891e-03, -5.2907e-03],
#           [ 5.5169e-01,  1.1040e-01, -5.3109e-03,  ..., -3.4073e-03,
#             7.3168e-01,  1.1076e+00],
#           [-2.4938e-03,  4.1073e-01,  5.0303e-01,  ..., -1.2286e-02,
#             7.8582e-01,  2.4380e-01]]]], device='cuda:0',
#        grad_fn=<InPlaceABNBackward>)

# %%
model._blocks
# Out:
# ModuleList(
#   (0): MBConvBlock(
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       48, 48, kernel_size=(3, 3), stride=[1, 1], groups=48, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(48, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(24, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (1): MBConvBlock(
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(24, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(24, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (2): MBConvBlock(
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(24, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(24, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (3): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(144, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       144, 144, kernel_size=(3, 3), stride=[2, 2], groups=144, bias=False
#       (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(144, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(40, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (4): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(40, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (5): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(40, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (6): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(40, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (7): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(40, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (8): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       240, 240, kernel_size=(5, 5), stride=[2, 2], groups=240, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(240, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       240, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(64, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (9): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(64, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (10): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(64, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (11): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(64, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (12): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       384, 384, kernel_size=(5, 5), stride=(1, 1), groups=384, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(64, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (13): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       384, 384, kernel_size=(3, 3), stride=[2, 2], groups=384, bias=False
#       (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(384, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (14): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (15): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (16): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (17): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (18): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (19): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       768, 768, kernel_size=(3, 3), stride=(1, 1), groups=768, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(128, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (20): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       768, 768, kernel_size=(5, 5), stride=[1, 1], groups=768, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(768, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       768, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (21): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (22): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (23): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (24): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (25): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (26): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1056, 1056, kernel_size=(5, 5), stride=(1, 1), groups=1056, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(176, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (27): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1056, 1056, kernel_size=(5, 5), stride=[2, 2], groups=1056, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1056, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1056, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (28): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (29): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (30): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (31): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (32): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (33): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (34): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (35): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1824, 1824, kernel_size=(5, 5), stride=(1, 1), groups=1824, bias=False
#       (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#     )
#     (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(304, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (36): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       1824, 1824, kernel_size=(3, 3), stride=[1, 1], groups=1824, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(1824, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       1824, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(512, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (37): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(3072, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       3072, 3072, kernel_size=(3, 3), stride=(1, 1), groups=3072, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(3072, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(512, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
#   (38): MBConvBlock(
#     (_expand_conv): Conv2dStaticSamePadding(
#       512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn0): InPlaceABN(3072, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_depthwise_conv): Conv2dStaticSamePadding(
#       3072, 3072, kernel_size=(3, 3), stride=(1, 1), groups=3072, bias=False
#       (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#     )
#     (_bn1): InPlaceABN(3072, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#     (_project_conv): Conv2dStaticSamePadding(
#       3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn2): InPlaceABN(512, eps=1e-05, momentum=0.1, affine=True, activation=leaky_relu[0.01])
#   )
# )
